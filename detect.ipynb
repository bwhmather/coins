# %%
% pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['draw']
# `%pylab --no-import-all` prevents importing * from pylab and numpy

# %%
from imp import reload

# %%
import numpy as np
import scipy as sp
from scipy.ndimage.filters import sobel, gaussian_filter

import matplotlib as mpl
mpl.rcParams['figure.figsize']=(16.0,12.0)

import matplotlib.pyplot as plt

from skimage import filter, transform, color, img_as_float, feature
from skimage.draw import circle_perimeter, set_color


#import coins

# %%
reload(coins)
# Out:
# <module 'coins' from './coins/__init__.py'>

# %%
#image = transform.rescale(imread('data/IMG_20131010_185412.jpg'), 0.5)
image = transform.rescale(imread('data/IMG_20131010_185626.jpg'), 0.5)

image = color.rgb2gray(image)
image = img_as_float(image)

# %%
circles = coins.detect_circles(image)
x_coords, y_coords, radii, weights = circles
# Out:
# 1.0
# 0.9093137254901961
# 0.826797385620915
# 0.7516339869281046
# 0.6838235294117647
# 0.6217320261437909
# 0.565359477124183
# 0.5147058823529411
# 0.4681372549019608
# 0.4256535947712418
# 0.3872549019607843
# 0.352124183006536
# 0.3202614379084967
# 0.2916666666666667
# 0.26552287581699346
# 0.24183006535947713
# 0.22058823529411764
# 0.20098039215686275
# 0.1830065359477124
# 0.16666666666666666
# 0.15196078431372548
# 0.1388888888888889
# 0.12663398692810457
# 0.11519607843137254
# 0.1053921568627451
# 0.09640522875816994
# 0.08823529411764706
# 0.08088235294117647
# 0.07352941176470588
# 0.06699346405228758
# 0.061274509803921566
# 0.056372549019607844
# 0.051470588235294115
# 0.04738562091503268
# 0.04330065359477124
# 0.04003267973856209
# 0.03676470588235294
# 0.03349673202614379
# 0.03104575163398693
# 0.028594771241830064
# 0.026143790849673203
# 0.024509803921568627
# 0.02287581699346405
# 0.021241830065359478
# 0.0196078431372549
# 0.017973856209150325
# 0.016339869281045753
# 0.015522875816993464
# 0.014705882352941176

# %%
order = weights.argsort()
sorted_x_coords = x_coords[order][-70:]
sorted_y_coords = y_coords[order][-70:]
sorted_radii = radii[order][-70:]
sorted_weights = weights[order][-70:]

# %%
borders = color.gray2rgb(image)
for x, y, r, w in zip(sorted_x_coords, sorted_y_coords, sorted_radii, sorted_weights):
    cx, cy = circle_perimeter(int(x), int(y), int(r))
    set_color(borders, (cx, cy), (220, 20, 20))

imshow(borders, cmap=plt.cm.gray)

# %%
scatter(weights, radii)

# %%
sorted_weights[sorted_weights>2]
# Out:
# array([ 2.01839907,  2.30292621])
